# %%
import pandas as pd
import matplotlib.pyplot as plt
import urllib.request
from gensim.models.word2vec import Word2Vec
from konlpy.tag import Okt

# %%
df = pd.read_csv(r'C:\Users\Lee seohyun\Downloads\kobert연습용.csv',encoding='CP949')
df
# Out:
#                                                    text  code
# 0                                       쓰레기 영화 돈OO하지마세요     0
# 1     이세상의 모든짐은 여자가 혼자 다 짊어지고 산다  남자는 이세상의 모든 혜택을 받으...   101
# 2                                             평점9 6 실화냐     0
# 3     아니 90년대생 여자들이 이걸보고 왜 공감을해   60 70이면 모를까  니들은 왜...     0
# 4                                          와 이런 영화가 허허참     0
# ...                                                 ...   ...
# 1394                                       전라도에서 예매율 1위    10
# 1395                                      82Kg 김치영 82kg   100
# 1396                                 개똥철학  0점을 못줘서 아쉽다      0
# 1397  같은세대를 살아가는 기혼 직장인입니다만 영확적재미를 위한 비약이 너무 심해서 공감가...     0
# 1398  고등학생때는 아이돌 배우빨아대다가대학교 그냥저냥 다니고 졸업하고 취직명품은 패시브였...   100
#
# [1399 rows x 2 columns]

# %%
stopwords = ['의','가','이','은','들','는','좀','잘','걍','과','도','를','으로','자','에','와','한','하다','것']

# %% [markdown]
# ## 데이터 정제

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import urllib.request
from collections import Counter
from konlpy.tag import Mecab
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
train_data, test_data = train_test_split(df, test_size = 0.25, random_state = 42)

# %%
okt = Okt()
tokenized_train = []
for sentence in train_data['text']:
    temp_X = okt.nouns(sentence) # 토큰화
    temp_X = [word for word in temp_X if not word in stopwords] # 불용어 제거
    tokenized_train.append(temp_X)

# %%
okt = Okt()
tokenized_test = []
for sentence in test_data['text']:
    temp_X = okt.nouns(sentence) # 토큰화
    temp_X = [word for word in temp_X if not word in stopwords] # 불용어 제거
    tokenized_test.append(temp_X)

# %%
X_train = tokenized_train
y_train = train_data['code'].values
X_test= tokenized_test
y_test = test_data['code'].values

# %% [markdown]
# ## 정수인코딩

# %%
tokenizer=Tokenizer()

# %%
tokenizer.fit_on_texts(X_train)

# %%
tokenizer.word_index
# Out:
# {'영화': 1,
#  '여자': 2,
#  '점': 3,
#  '남자': 4,
#  '진짜': 5,
#  '공감': 6,
#  '말': 7,
#  '페미': 8,
#  '돈': 9,
#  '김지영': 10,
#  '선동': 11,
#  '뭐': 12,
#  '정치': 13,
#  '거': 14,
#  '북한': 15,
#  '생각': 16,
#  '여성': 17,
#  '그냥': 18,
#  '쿵쾅': 19,
#  '쓰레기': 20,
#  '평점': 21,
#  '사람': 22,
#  '남녀': 23,
#  '최악': 24,
#  '갈등': 25,
#  '그': 26,
#  '보고': 27,
#  '조장': 28,
#  '왜': 29,
#  '노잼': 30,
#  '걸': 31,
#  '이해': 32,
#  '더': 33,
#  '정말': 34,
#  '세대': 35,
#  '정권': 36,
#  '재미': 37,
#  '연기': 38,
#  '미화': 39,
#  '시간': 40,
#  '때': 41,
#  '현실': 42,
#  '빨갱이': 43,
#  '임': 44,
#  '좌파': 45,
#  '내용': 46,
#  '이건': 47,
#  '개': 48,
#  '감독': 49,
#  '니': 50,
#  '위': 51,
#  '감동': 52,
#  '역사': 53,
#  '사회': 54,
#  '대한민국': 55,
#  '세상': 56,
#  '일': 57,
#  '우리': 58,
#  '내': 59,
#  '게': 60,
#  '모든': 61,
#  '한국': 62,
#  '스토리': 63,
#  '때문': 64,
#  '나라': 65,
#  '지금': 66,
#  '대통령': 67,
#  '자체': 68,
#  '색': 69,
#  '정신병': 70,
#  '사실': 71,
#  '시대': 72,
#  '이야기': 73,
#  '질': 74,
#  '애': 75,
#  '안': 76,
#  '정도': 77,
#  '하나': 78,
#  '소설': 79,
#  '수준': 80,
#  '맘충': 81,
#  '남편': 82,
#  '책': 83,
#  '줄': 84,
#  '문제': 85,
#  '댓글': 86,
#  '뿐': 87,
#  '탓': 88,
#  '자기': 89,
#  '영화로': 90,
#  '움': 91,
#  '보지': 92,
#  '배우': 93,
#  '나': 94,
#  '왜곡': 95,
#  '연출': 96,
#  '어머니': 97,
#  '남성': 98,
#  '알바': 99,
#  '부분': 100,
#  '공유': 101,
#  '작품': 102,
#  '제발': 103,
#  '김대중': 104,
#  '별로': 105,
#  '피해망상': 106,
#  '수': 107,
#  '피해': 108,
#  '볼': 109,
#  '결혼': 110,
#  '년': 111,
#  '좌빨': 112,
#  '인생': 113,
#  '메': 114,
#  '함': 115,
#  '절대': 116,
#  '무슨': 117,
#  '분': 118,
#  '요즘': 119,
#  '누구': 120,
#  '박정희': 121,
#  '김재규': 122,
#  '피해자': 123,
#  '처음': 124,
#  '전혀': 125,
#  '엄마': 126,
#  '또': 127,
#  '페미니즘': 128,
#  '못': 129,
#  '점도': 130,
#  '마음': 131,
#  '의도': 132,
#  '조커': 133,
#  '차별': 134,
#  '건': 135,
#  '영혼': 136,
#  '꼴': 137,
#  '인정': 138,
#  '혼자': 139,
#  '억지': 140,
#  '혐오': 141,
#  '판타지': 142,
#  '원작': 143,
#  '모두': 144,
#  '자신': 145,
#  '감성': 146,
#  '소리': 147,
#  '찬양': 148,
#  '가장': 149,
#  '대한': 150,
#  '이유': 151,
#  '상황': 152,
#  '추천': 153,
#  '영화관': 154,
#  '해도': 155,
#  '서로': 156,
#  '픽션': 157,
#  '듯': 158,
#  '일반': 159,
#  '마냥': 160,
#  '요': 161,
#  '이제': 162,
#  '우리나라': 163,
#  '위해': 164,
#  '한국영': 165,
#  '어디': 166,
#  '핵': 167,
#  '페미니스트': 168,
#  '욕': 169,
#  '본인': 170,
#  '능력': 171,
#  '여기': 172,
#  '의식': 173,
#  '환자': 174,
#  '명': 175,
#  '딸': 176,
#  '제': 177,
#  '난': 178,
#  '기': 179,
#  '주인공': 180,
#  '국가': 181,
#  '다큐': 182,
#  '육아': 183,
#  '중': 184,
#  '이상': 185,
#  '광기': 186,
#  '입장': 187,
#  '한번': 188,
#  '희생': 189,
#  '살': 190,
#  '표현': 191,
#  '고생': 192,
#  '남': 193,
#  '꼭': 194,
#  '끝': 195,
#  '드라마': 196,
#  '성향': 197,
#  '주의': 198,
#  '혜택': 199,
#  '보기': 200,
#  '가지': 201,
#  '아주': 202,
#  '군대': 203,
#  '삶': 204,
#  '세계': 205,
#  '보수': 206,
#  '이병헌': 207,
#  '가정': 208,
#  '얼마나': 209,
#  '아들': 210,
#  '편향': 211,
#  '감': 212,
#  '지영': 213,
#  '정부': 214,
#  '위로': 215,
#  '작가': 216,
#  '가족': 217,
#  '이용': 218,
#  '톤': 219,
#  '제목': 220,
#  '묘사': 221,
#  '똥': 222,
#  '정신': 223,
#  '황정민': 224,
#  '인간': 225,
#  '좌편향': 226,
#  '흐름': 227,
#  '차라리': 228,
#  '개인': 229,
#  '불만': 230,
#  '이면': 231,
#  '조작': 232,
#  '녀': 233,
#  '성별': 234,
#  '역대': 235,
#  '친북': 236,
#  '평가': 237,
#  '대의': 238,
#  '사상': 239,
#  '돼지': 240,
#  '빠순이': 241,
#  '저': 242,
#  '제일': 243,
#  '이후': 244,
#  '글': 245,
#  '용': 246,
#  '기적': 247,
#  '좌좀': 248,
#  '개돼지': 249,
#  '거짓': 250,
#  '사건': 251,
#  '팩트': 252,
#  '알': 253,
#  '마치': 254,
#  '국민': 255,
#  '데': 256,
#  '프로': 257,
#  '날': 258,
#  '다른': 259,
#  '군': 260,
#  '개봉': 261,
#  '온갖': 262,
#  '일단': 263,
#  '이기': 264,
#  '진심': 265,
#  '이슈': 266,
#  '선거': 267,
#  '집': 268,
#  '해': 269,
#  '역시': 270,
#  '오히려': 271,
#  '뒤': 272,
#  '대사': 273,
#  '오지': 274,
#  '문재인': 275,
#  '한쪽': 276,
#  '정상': 277,
#  '존재': 278,
#  '최고': 279,
#  '정치인': 280,
#  '한마디': 281,
#  '도대체': 282,
#  '답': 283,
#  '후': 284,
#  '집안일': 285,
#  '아버지': 286,
#  '아이': 287,
#  '주부': 288,
#  '불행': 289,
#  '망상': 290,
#  '실화': 291,
#  '쿵': 292,
#  '착각': 293,
#  '영화인': 294,
#  '적': 295,
#  '중간': 296,
#  '살기': 297,
#  '평': 298,
#  '총선': 299,
#  '경제': 300,
#  '쪽': 301,
#  '연평도': 302,
#  '별': 303,
#  '마지막': 304,
#  '열': 305,
#  '너': 306,
#  '우파': 307,
#  '인물': 308,
#  '영웅': 309,
#  '속': 310,
#  '한편': 311,
#  '주작': 312,
#  '지루함': 313,
#  '조금': 314,
#  '이영화': 315,
#  '어이': 316,
#  '가슴': 317,
#  '전형': 318,
#  '새끼': 319,
#  '놈': 320,
#  '설명': 321,
#  '일베': 322,
#  '짓': 323,
#  '인권': 324,
#  '코인': 325,
#  '간다': 326,
#  '응': 327,
#  '선': 328,
#  '아빠': 329,
#  '꿀': 330,
#  '빨': 331,
#  '화보': 332,
#  '잠': 333,
#  '여자친구': 334,
#  '관람': 335,
#  '어거지': 336,
#  '누가': 337,
#  '법': 338,
#  '날조': 339,
#  '진보': 340,
#  '시절': 341,
#  '거의': 342,
#  '몰입': 343,
#  '로서': 344,
#  '무조건': 345,
#  '우월': 346,
#  '대부분': 347,
#  '경험': 348,
#  '류': 349,
#  '맘': 350,
#  '뭘': 351,
#  '된장녀': 352,
#  '오늘': 353,
#  '장면': 354,
#  '공작': 355,
#  '저런': 356,
#  '처럼': 357,
#  '얘기': 358,
#  '한숨': 359,
#  '식': 360,
#  '몰카': 361,
#  '처': 362,
#  '미래': 363,
#  '상영': 364,
#  '쾅': 365,
#  '잘못': 366,
#  '상업': 367,
#  '간첩': 368,
#  '관객': 369,
#  '시댁': 370,
#  '부탁': 371,
#  '맙시': 372,
#  '구': 373,
#  '정유미': 374,
#  '제작': 375,
#  '요약': 376,
#  '기분': 377,
#  '세뇌': 378,
#  '영': 379,
#  '여자라서': 380,
#  '남탓': 381,
#  '라면': 382,
#  '계속': 383,
#  '수가': 384,
#  '이번': 385,
#  '옆': 386,
#  '암살': 387,
#  '남산': 388,
#  '영상': 389,
#  '이하': 390,
#  '과장': 391,
#  '부모님': 392,
#  '눈물': 393,
#  '역차별': 394,
#  '김정은': 395,
#  '선택': 396,
#  '코스프레': 397,
#  '정상인': 398,
#  '증거': 399,
#  '커피': 400,
#  '엄복동': 401,
#  '도안': 402,
#  '조폭': 403,
#  '어쩌': 404,
#  '역사상': 405,
#  '집단': 406,
#  '예술': 407,
#  '소름': 408,
#  '흠': 409,
#  '극혐': 410,
#  '내내': 411,
#  '진화': 412,
#  '차': 413,
#  '차이': 414,
#  '비교': 415,
#  '일본': 416,
#  '그것': 417,
#  '분열': 418,
#  '어머님': 419,
#  '삭제': 420,
#  '편견': 421,
#  '고': 422,
#  '재앙': 423,
#  '띠': 424,
#  '비': 425,
#  '불': 426,
#  '기억': 427,
#  '도발': 428,
#  '주장': 429,
#  '글쎄': 430,
#  '낭비': 431,
#  '김': 432,
#  '좌': 433,
#  '패': 434,
#  '저리': 435,
#  '앞': 436,
#  '부장': 437,
#  '전': 438,
#  '테러': 439,
#  '며느리': 440,
#  '는걸': 441,
#  '사례': 442,
#  '아무': 443,
#  '대가리': 444,
#  '밖': 445,
#  '액션': 446,
#  '독박': 447,
#  '어린이집': 448,
#  '공': 449,
#  '문화': 450,
#  '산': 451,
#  '라지': 452,
#  '옹호': 453,
#  '감상': 454,
#  '아내': 455,
#  '시기': 456,
#  '화장실': 457,
#  '뇌': 458,
#  '부정': 459,
#  '선입견': 460,
#  '현': 461,
#  '관점': 462,
#  '반응': 463,
#  '머리': 464,
#  '접': 465,
#  '색깔': 466,
#  '그대로': 467,
#  '시점': 468,
#  '겨우': 469,
#  '비정상': 470,
#  '걱정': 471,
#  '연평해전': 472,
#  '자꾸': 473,
#  '김철수': 474,
#  '의무': 475,
#  '화가': 476,
#  '연기력': 477,
#  '노무현': 478,
#  '정보': 479,
#  '빼': 480,
#  '거른다': 481,
#  '전부': 482,
#  '투정': 483,
#  '소재': 484,
#  '옛날': 485,
#  '장난': 486,
#  '작전': 487,
#  '민주당': 488,
#  '결론': 489,
#  '비판': 490,
#  '감정': 491,
#  '열등감': 492,
#  '본적': 493,
#  '애초': 494,
#  '대변': 495,
#  '여자도': 496,
#  '실제': 497,
#  '첩보': 498,
#  '부': 499,
#  '가야': 500,
#  '존나': 501,
#  '하니': 502,
#  '중국': 503,
#  '양심': 504,
#  '줌': 505,
#  '독재': 506,
#  '상상': 507,
#  '충': 508,
#  '거기': 509,
#  '랍시고': 510,
#  '등': 511,
#  '힘': 512,
#  '굳이': 513,
#  '전세계': 514,
#  '국방': 515,
#  '물': 516,
#  '우울증': 517,
#  '하루': 518,
#  '나중': 519,
#  '너희': 520,
#  '아침': 521,
#  '다가': 522,
#  '남여': 523,
#  '수면제': 524,
#  '북괴': 525,
#  '번': 526,
#  '남성혐오': 527,
#  '길': 528,
#  '가득': 529,
#  '가산': 530,
#  '포인트': 531,
#  '생활': 532,
#  '스스로': 533,
#  '균형': 534,
#  '깨': 535,
#  '완성': 536,
#  '퉤': 537,
#  '누군가': 538,
#  '울': 539,
#  '행동': 540,
#  '신': 541,
#  '편파': 542,
#  '뻔': 543,
#  '후반': 544,
#  '긴장감': 545,
#  '배경': 546,
#  '점수': 547,
#  '기본': 548,
#  '팔이': 549,
#  '메시지': 550,
#  '이정': 551,
#  '빙의': 552,
#  '확': 553,
#  '지루': 554,
#  '설정': 555,
#  '생': 556,
#  '가면': 557,
#  '빼액': 558,
#  '마누라': 559,
#  '볼껄': 560,
#  '안기부': 561,
#  '또한': 562,
#  '투덜': 563,
#  '극히': 564,
#  '주변': 565,
#  '시작': 566,
#  '애액': 567,
#  '거름': 568,
#  '페미나치': 569,
#  '분쟁': 570,
#  '행위': 571,
#  '아이돌': 572,
#  '달창': 573,
#  '친구': 574,
#  '느낌': 575,
#  '볼걸': 576,
#  '김치': 577,
#  '리': 578,
#  '건가': 579,
#  '개발': 580,
#  '끼리': 581,
#  '병': 582,
#  '아부': 583,
#  '분위기': 584,
#  '하위': 585,
#  '급': 586,
#  '기도': 587,
#  '눈': 588,
#  '업무': 589,
#  '마케팅': 590,
#  '매우': 591,
#  '율': 592,
#  '가치': 593,
#  '당선': 594,
#  '냄새': 595,
#  '현대': 596,
#  '성인': 597,
#  '등등': 598,
#  '대가': 599,
#  '인': 600,
#  '거리': 601,
#  '거부': 602,
#  '할머니': 603,
#  '번식': 604,
#  '최': 605,
#  '직장': 606,
#  '대체': 607,
#  '여친': 608,
#  '철': 609,
#  '포기': 610,
#  '강제': 611,
#  '제대로': 612,
#  '뭣': 613,
#  '잼': 614,
#  '북': 615,
#  '살인자': 616,
#  '가짜': 617,
#  '대상': 618,
#  '친정엄마': 619,
#  '인척': 620,
#  '지능': 621,
#  '성적': 622,
#  '모습': 623,
#  '카페': 624,
#  '시어머니': 625,
#  '승진': 626,
#  '항상': 627,
#  '팝콘': 628,
#  '티켓': 629,
#  '값': 630,
#  '직접': 631,
#  '회사': 632,
#  '배제': 633,
#  '기능': 634,
#  '궁': 635,
#  '환경': 636,
#  '일방': 637,
#  '틀': 638,
#  '얼마': 639,
#  '극': 640,
#  '아예': 641,
#  '급진': 642,
#  '빵점': 643,
#  '극단': 644,
#  '적임': 645,
#  '잌': 646,
#  '여당': 647,
#  '야당': 648,
#  '퉷': 649,
#  '과도': 650,
#  '발전': 651,
#  '각색': 652,
#  '정의': 653,
#  '리가': 654,
#  '숙면': 655,
#  '여주': 656,
#  '커녕': 657,
#  '요소': 658,
#  '유가족': 659,
#  '자리': 660,
#  '과대망상': 661,
#  '증': 662,
#  '아줌마': 663,
#  '신세': 664,
#  '대인배': 665,
#  '터미네이터': 666,
#  '옴': 667,
#  '개월': 668,
#  '단지': 669,
#  '정신승리': 670,
#  '표본': 671,
#  '뭔가': 672,
#  '심화': 673,
#  '올해': 674,
#  '악의': 675,
#  '저걸': 676,
#  '민족': 677,
#  '습': 678,
#  '당신': 679,
#  '민주주의': 680,
#  '절친': 681,
#  '식당': 682,
#  '중앙': 683,
#  '경제성장': 684,
#  '벌써': 685,
#  '껏': 686,
#  '민국': 687,
#  '장르': 688,
#  '률': 689,
#  '시험': 690,
#  '공부': 691,
#  '네': 692,
#  '컵': 693,
#  '홍보': 694,
#  '핵대중': 695,
#  '신격화': 696,
#  '평론가': 697,
#  '이미지': 698,
#  '출연': 699,
#  '상해': 700,
#  '상승': 701,
#  '막상': 702,
#  '관계': 703,
#  '범죄자': 704,
#  '면서': 705,
#  '사과': 706,
#  '의심': 707,
#  '리뷰': 708,
#  '출산율': 709,
#  '압도': 710,
#  '삐': 711,
#  '안보': 712,
#  '응원': 713,
#  '상관': 714,
#  '지배': 715,
#  '어제': 716,
#  '박통': 717,
#  '지네': 718,
#  '테': 719,
#  '누리': 720,
#  '결코': 721,
#  '행복': 722,
#  '나팔수': 723,
#  '덜': 724,
#  '해석': 725,
#  '영화계': 726,
#  '장악': 727,
#  '결과': 728,
#  '일지': 729,
#  '악': 730,
#  '을해': 731,
#  '머': 732,
#  '탈': 733,
#  '이지': 734,
#  '솔솔': 735,
#  '불면증': 736,
#  '네이버': 737,
#  '여성혐오': 738,
#  '명분': 739,
#  '생산': 740,
#  '중립': 741,
#  '유': 742,
#  '한남': 743,
#  '이성민': 744,
#  '분란': 745,
#  '아카데미': 746,
#  '평등': 747,
#  '신파': 748,
#  '거르': 749,
#  '질질': 750,
#  '성형': 751,
#  '범': 752,
#  '레전드': 753,
#  '가라': 754,
#  '실망': 755,
#  '조진웅': 756,
#  '다': 757,
#  '웃기': 758,
#  '온': 759,
#  '김일성': 760,
#  '현재': 761,
#  '산다': 762,
#  '관객수': 763,
#  '난리': 764,
#  '거지': 765,
#  '리얼': 766,
#  '루': 767,
#  '기껏': 768,
#  '종일': 769,
#  '개연': 770,
#  '등장': 771,
#  '달': 772,
#  '십': 773,
#  '가관': 774,
#  '버': 775,
#  '시각': 776,
#  '기반': 777,
#  '갈수록': 778,
#  '로만': 779,
#  '간': 780,
#  '옹': 781,
#  '각종': 782,
#  '통계': 783,
#  '근거': 784,
#  '대해': 785,
#  '객관': 786,
#  '지표': 787,
#  '대중성': 788,
#  '근본': 789,
#  '단순': 790,
#  '최대': 791,
#  '망': 792,
#  '맛': 793,
#  '제로': 794,
#  '전사': 795,
#  '개판': 796,
#  '남한': 797,
#  '국정원': 798,
#  '사주': 799,
#  '라며': 800,
#  '반대': 801,
#  '피해망상증': 802,
#  '키': 803,
#  '검색': 804,
#  '공산당': 805,
#  '암': 806,
#  '편협': 807,
#  '꼴깝': 808,
#  '주접': 809,
#  '여자애': 810,
#  '보': 811,
#  '세': 812,
#  '부양': 813,
#  '면': 814,
#  '역사왜곡': 815,
#  '개정': 816,
#  '바': 817,
#  '창': 818,
#  '개입': 819,
#  '영화감독': 820,
#  '시나리오': 821,
#  '일부': 822,
#  '목적': 823,
#  '목소리': 824,
#  '아웃': 825,
#  '국적': 826,
#  '기모': 827,
#  '일주일': 828,
#  '푹': 829,
#  '자위': 830,
#  '에이': 831,
#  '구석': 832,
#  '입맛': 833,
#  '주의자': 834,
#  '원조': 835,
#  '골빈': 836,
#  '데리': 837,
#  '씬': 838,
#  '오': 839,
#  '박': 840,
#  '재': 841,
#  '집중': 842,
#  '안남': 843,
#  '이효리': 844,
#  '생기': 845,
#  '잠재': 846,
#  '성범죄자': 847,
#  '불평': 848,
#  '례': 849,
#  '한창': 850,
#  '라이': 851,
#  '경계': 852,
#  '무너': 853,
#  '편': 854,
#  '독': 855,
#  '봣': 856,
#  '덕분': 857,
#  '파악': 858,
#  '속지': 859,
#  '언제': 860,
#  '출생': 861,
#  '만큼': 862,
#  '그다지': 863,
#  '과연': 864,
#  '초등학교': 865,
#  '중학교': 866,
#  '배': 867,
#  '테크': 868,
#  '상위': 869,
#  '평타': 870,
#  '내면': 871,
#  '포장': 872,
#  '역할': 873,
#  '불합리': 874,
#  '베셀': 875,
#  '흥행': 876,
#  '화의': 877,
#  '어벤져스': 878,
#  '예매': 879,
#  '통': 880,
#  '달라': 881,
#  '점주': 882,
#  '가요': 883,
#  '다운': 884,
#  '감안': 885,
#  '자라': 886,
#  '안나': 887,
#  '절': 888,
#  '차원': 889,
#  '일이': 890,
#  '필요': 891,
#  '동안': 892,
#  '백두산': 893,
#  '등록': 894,
#  '김영삼': 895,
#  '일도': 896,
#  '슨상님': 897,
#  '당': 898,
#  '고충': 899,
#  '악질': 900,
#  '나이': 901,
#  '우상화': 902,
#  '한나라당': 903,
#  '토착': 904,
#  '왜구': 905,
#  '려': 906,
#  '동의': 907,
#  '셈': 908,
#  '화판': 909,
#  '따위': 910,
#  '수용': 911,
#  '후회': 912,
#  '싸움': 913,
#  '노력': 914,
#  '음': 915,
#  '텅텅': 916,
#  '신의한수': 917,
#  '주차장': 918,
#  '장애인': 919,
#  '비용': 920,
#  '부담': 921,
#  '비율': 922,
#  '암컷': 923,
#  '학원': 924,
#  '참고': 925,
#  '직장인': 926,
#  '야근': 927,
#  '사랑': 928,
#  '아대': 929,
#  '판결': 930,
#  '국밥': 931,
#  '형편': 932,
#  '군가산점': 933,
#  '남녀평등': 934,
#  '폐지': 935,
#  '과실': 936,
#  '더욱': 937,
#  '업적': 938,
#  '기리': 939,
#  '배려': 940,
#  '요구': 941,
#  '대학': 942,
#  '고민': 943,
#  '내년': 944,
#  '중심': 945,
#  '졸업': 946,
#  '적응': 947,
#  '벌': 948,
#  '전체': 949,
#  '가기': 950,
#  '선물': 951,
#  '공짜': 952,
#  '호구': 953,
#  '허구': 954,
#  '창작': 955,
#  '화제': 956,
#  '롤렉스': 957,
#  '팬': 958,
#  '만하': 959,
#  '추구': 960,
#  '손가락': 961,
#  '코미디': 962,
#  '지진': 963,
#  '이자': 964,
#  '즘': 965,
#  '조선': 966,
#  '깔깔': 967,
#  '끝판': 968,
#  '일기장': 969,
#  '참나': 970,
#  '벌이': 971,
#  '친정': 972,
#  '전업': 973,
#  '조센징': 974,
#  '곧': 975,
#  '억지로': 976,
#  '최대한': 977,
#  '당사자': 978,
#  '분명': 979,
#  '관': 980,
#  '집안': 981,
#  '매사': 982,
#  '완전': 983,
#  '인양': 984,
#  '고통': 985,
#  '부족': 986,
#  '주입': 987,
#  '장창': 988,
#  '클라스': 989,
#  '맘마미아': 990,
#  '코르셋': 991,
#  '탈락': 992,
#  '향': 993,
#  '상의': 994,
#  '실수': 995,
#  '부모': 996,
#  '뉴스': 997,
#  '판단': 998,
#  '벌점': 999,
#  '환불': 1000,
#  ...}

# %%
threshold = 2
total_cnt = len(tokenizer.word_index) # 단어의 수
rare_cnt = 0 # 등장 빈도수가 threshold보다 작은 단어의 개수를 카운트
total_freq = 0 # 훈련 데이터의 전체 단어 빈도수 총 합
rare_freq = 0 # 등장 빈도수가 threshold보다 작은 단어의 등장 빈도수의 총 합

# 단어와 빈도수의 쌍(pair)을 key와 value로 받는다.
for key, value in tokenizer.word_counts.items():
    total_freq = total_freq + value

    # 단어의 등장 빈도수가 threshold보다 작으면
    if(value < threshold):
        rare_cnt = rare_cnt + 1
        rare_freq = rare_freq + value

print('단어 집합(vocabulary)의 크기 :',total_cnt)
print('등장 빈도가 %s번 이하인 희귀 단어의 수: %s'%(threshold - 1, rare_cnt))
print("단어 집합에서 희귀 단어의 비율:", (rare_cnt / total_cnt)*100)
print("전체 등장 빈도에서 희귀 단어 등장 빈도 비율:", (rare_freq / total_freq)*100)
# Out:
# 단어 집합(vocabulary)의 크기 : 2479
# 등장 빈도가 1번 이하인 희귀 단어의 수: 1460
# 단어 집합에서 희귀 단어의 비율: 58.89471561113352
# 전체 등장 빈도에서 희귀 단어 등장 빈도 비율: 16.929499072356215

# %%
# 전체 단어 개수 중 빈도수 2이하인 단어 개수는 제거.
# 0번 패딩 토큰과 1번 OOV 토큰을 고려하여 +2
vocab_size = total_cnt - rare_cnt + 2
print('단어 집합의 크기 :',vocab_size)
# Out:
# 단어 집합의 크기 : 1021

# %%
tokenizer = Tokenizer(vocab_size, oov_token = 'OOV') 
tokenizer.fit_on_texts(X_train)
X_train = tokenizer.texts_to_sequences(X_train)
X_test = tokenizer.texts_to_sequences(X_test)

# %%
#정수 인코딩이 진행되었는지 확인
#print(X_test[:3])
print(X_train[:3])
# Out:
# [[83, 33, 28, 73, 61, 83, 291, 24, 74], [458, 291, 246, 91, 363, 62, 35, 186, 364], [102, 103]]

# %% [markdown]
# ## 패딩

# %%
print('리뷰의 최대 길이 :',max(len(l) for l in X_train))
print('리뷰의 평균 길이 :',sum(map(len, X_train))/len(X_train))
plt.hist([len(s) for s in X_train], bins=50)
plt.xlabel('length of samples')
plt.ylabel('number of samples')
plt.show()
# Out:
# 리뷰의 최대 길이 : 179
# 리뷰의 평균 길이 : 8.221163012392754

# %%
def below_threshold_len(max_len, nested_list):
  cnt = 0
  for s in nested_list:
    if(len(s) <= max_len):
        cnt = cnt + 1
  print('전체 샘플 중 길이가 %s 이하인 샘플의 비율: %s'%(max_len, (cnt / len(nested_list))*100))

# %%
max_len = 60
below_threshold_len(max_len, X_train)
# Out:
# 전체 샘플 중 길이가 60 이하인 샘플의 비율: 98.95138226882746

# %%
X_train = pad_sequences(X_train, maxlen = max_len)
X_test = pad_sequences(X_test, maxlen = max_len)

# %% [markdown]
# ## Bi-LSTM

# %%
import re
from tensorflow.keras.layers import Embedding, Dense, LSTM, Bidirectional
from tensorflow.keras.models import Sequential
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
model = Sequential()
model.add(Embedding(vocab_size, 500))
model.add(Bidirectional(LSTM(500)))
model.add(Dense(1, activation='sigmoid'))
model.add(Conv2D(50, kernel_size=(50, 500), activation="relu"))
model.add(MaxPool2D(pool_size=(1000 - 50 + 1, 1)))
model.add(Flatten())
model.add(GlobalAvgPool1D())
model.add(Dense(500, activation="sigmoid", use_bias=True))
model.add(Multiply())

# %%
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=4)
mc = ModelCheckpoint('best_model.h5', monitor='val_acc', mode='max', verbose=1, save_best_only=True)

# %%
model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['acc'])
history = model.fit(X_train, y_train, epochs=15, callbacks=[es, mc], batch_size=256, validation_split=0.2)
# Out:
# Epoch 1/15
# 4/4 [==============================] - 89s 18s/step - loss: -126.4794 - acc: 0.2551 - val_loss: -416.3956 - val_acc: 0.0333
#
# Epoch 00001: val_acc improved from -inf to 0.03333, saving model to best_model.h5
# Epoch 2/15
# 4/4 [==============================] - 101s 23s/step - loss: -591.0808 - acc: 0.0501 - val_loss: -640.2222 - val_acc: 0.0333
#
# Epoch 00002: val_acc did not improve from 0.03333
# Epoch 3/15
# 4/4 [==============================] - 98s 22s/step - loss: -800.3483 - acc: 0.0501 - val_loss: -743.8057 - val_acc: 0.0333
#
# Epoch 00003: val_acc did not improve from 0.03333
# Epoch 4/15
# 4/4 [==============================] - 79s 19s/step - loss: -911.5242 - acc: 0.0501 - val_loss: -818.4734 - val_acc: 0.0333
#
# Epoch 00004: val_acc did not improve from 0.03333
# Epoch 5/15
# 4/4 [==============================] - 83s 20s/step - loss: -995.3795 - acc: 0.0501 - val_loss: -880.2635 - val_acc: 0.0333
#
# Epoch 00005: val_acc did not improve from 0.03333
# Epoch 6/15
# 4/4 [==============================] - 87s 20s/step - loss: -1068.1254 - acc: 0.0501 - val_loss: -941.5057 - val_acc: 0.0333
#
# Epoch 00006: val_acc did not improve from 0.03333
# Epoch 7/15
# 4/4 [==============================] - 92s 23s/step - loss: -1139.0284 - acc: 0.0501 - val_loss: -995.2280 - val_acc: 0.0333
#
# Epoch 00007: val_acc did not improve from 0.03333
# Epoch 8/15
# 4/4 [==============================] - 85s 20s/step - loss: -1203.9087 - acc: 0.0501 - val_loss: -1051.0942 - val_acc: 0.0333
#
# Epoch 00008: val_acc did not improve from 0.03333
# Epoch 9/15
# 4/4 [==============================] - 83s 20s/step - loss: -1269.2678 - acc: 0.0501 - val_loss: -1104.3900 - val_acc: 0.0333
#
# Epoch 00009: val_acc did not improve from 0.03333
# Epoch 10/15
# 4/4 [==============================] - 80s 19s/step - loss: -1332.4403 - acc: 0.0501 - val_loss: -1156.1671 - val_acc: 0.0333
#
# Epoch 00010: val_acc did not improve from 0.03333
# Epoch 11/15
# 4/4 [==============================] - 96s 23s/step - loss: -1395.0385 - acc: 0.0501 - val_loss: -1215.8241 - val_acc: 0.0333
#
# Epoch 00011: val_acc did not improve from 0.03333
# Epoch 12/15
# 4/4 [==============================] - 120s 30s/step - loss: -1463.4775 - acc: 0.0501 - val_loss: -1263.1685 - val_acc: 0.0333
#
# Epoch 00012: val_acc did not improve from 0.03333
# Epoch 13/15
# 4/4 [==============================] - 122s 27s/step - loss: -1521.9310 - acc: 0.0501 - val_loss: -1321.8997 - val_acc: 0.0333
#
# Epoch 00013: val_acc did not improve from 0.03333
# Epoch 14/15
# 4/4 [==============================] - 88s 20s/step - loss: -1590.4242 - acc: 0.0501 - val_loss: -1375.7015 - val_acc: 0.0333
#
# Epoch 00014: val_acc did not improve from 0.03333
# Epoch 15/15
# 4/4 [==============================] - 87s 22s/step - loss: -1653.8342 - acc: 0.0501 - val_loss: -1423.3396 - val_acc: 0.0333
#
# Epoch 00015: val_acc did not improve from 0.03333

# %%
#테스트 정확도 
loaded_model = load_model('best_model.h5')
print("테스트 정확도: %.4f" % (loaded_model.evaluate(X_test, y_test)[1]))
